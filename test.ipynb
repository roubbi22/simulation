# %%
import networkx as nx

# %%
G = nx.Graph()

# %%
G.add_edge("A", "B", length=0.3, type="straight", vmax=1.0)
G.add_edge("A", "C", length=0.3, type="curve", vmax=0.6)

# %%
G["A"]["B"]
# Out:
# {'length': 0.3, 'type': 'straight', 'vmax': 1.0}
