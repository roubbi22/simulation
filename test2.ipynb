# %%
from model import SegmentStraight, EndVector

# %%
s1 = SegmentStraight(200)

# %%
s1.ends["b"].vector
# Out:
# EndVector(x=0, y=200, angle=0)

# %%
s1.translate(0, 200)

# %%
s1.ends["a"].vector
# Out:
# EndVector(x=0, y=200, angle=180)

# %%
type(s1.ends["a"].vector)
# Out:
# model.EndVector

# %%
test = (0, 0, 15)
type(test)
test[2]
# Out:
# 15

# %%
s1.rotate(180, "a")

# %%
print(s1.ends["a"].vector)
print(s1.ends["b"].vector)
# Out:
# EndVector(x=0, y=200, angle=180)
# EndVector(x=np.float64(-0.0), y=np.float64(0.0), angle=180)
