# %%
test_list = [0, 1, 2, 3, 4]

# %%
test_list[::-1]
# Out:
# [4, 3, 2, 1, 0]

# %%
test_list_shortened = test_list[1:-1]
test_list_shortened
# Out:
# [1, 2, 3]

# %%
test_list = [0]

# %%
test_list[0:6]
# Out:
# [0]

# %%
tuple_test = (1, (2, 3))

# %%
tuple_test[1][1]
# Out:
# 3

# %%
test_list2 = ["a", "b", "c", "d", "e"]

for i, item in enumerate(test_list2):
    print(i, item)
# Out:
# 0 a
# 1 b
# 2 c
# 3 d
# 4 e
